# %% [markdown]
# <a href="https://colab.research.google.com/github/Gibatijo/Exercicios/blob/main/1_aula_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input('Qual é seu nome?')
print('Seja bem vinda', nome)
# Out:
# Qual é seu nome?Giovanna
# Seja bem vinda Giovanna

# %%
dia = input("dia:")
mes = input('mes:')
ano = input('ano:')

print("Você nasceu no dia", dia, "no mes de", mes, "no ano", ano)
# Out:
# dia:07
# mes:05
# ano:2003
# Você nasceu no dia 07 no mes de 05 no ano 2003

# %%
a = input("digite um numero:")
b = input("digite outro numero:")
print(a + b)
print(int(a) + int(b))
# Out:
# digite um numero:5
# digite outro numero:5
# 55
# 10
