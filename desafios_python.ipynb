# %% [markdown]
# <a href="https://colab.research.google.com/github/Gibatijo/Exercicios/blob/main/desafios_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 001

# %%
print("Ola, mundo!")
# Out:
# Ola, mundo!

# %% [markdown]
# 002

# %%
nome = input('Digite seu nome: ')
print('Prazer em conhece-lo', nome)
# Out:
# Digite seu nome:GIo
# Prazer em conhece-lo GIo

# %% [markdown]
# 003

# %%
nome = input(f'Digite seu nome:')
print(f'Prazer em conhece-lo {nome}')
# Out:
# Digite seu nome:Antonio
# Prazer em conhece-lo Antonio

# %% [markdown]
# 004

# %%
a = int(input('digite um numero:'))
b = int(input('digite um numero:'))
s = a + b
print(f'a some de {a} + {b} é igual a {s}')
# Out:
# digite um numero:6
# digite um numero:9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-64f9c52c4056> in <cell line: 0>()
#       2 b = int(input('digite um numero:'))
#       3 s = a + b
# ----> 4 print(f'a some de {a} + {b} é igual a {S}')
#
# NameError: name 'S' is not defined

# %% [markdown]
# 005

# %%
v = input('digite um valor: ')
print('o valor digitado é numero: ', v.isalnum())
print('o valor digitado possui letra maiuscula: ', v.isupper())
print('o valor digitado possui letra minuscula: ', v.islower())
print('o valor digitado possui numero: ', v.isnumeric())
print('o valor digitado possui letras:', v.isalpha())
# Out:
# digite um valor: 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-be13f421022f> in <cell line: 0>()
#       1 v = input('digite um valor: ')
# ----> 2 print('o valor digitado é numero: ', v.isalnum())
#       3 print('o valor digitado possui letra maiuscula: ', v.isupper())
#       4 print('o valor digitado possui letra minuscula: ', v.islower())
#       5 print('o valor digitado possui numero: ', v.isnumeric())
#
# TypeError: str.isalnum() takes no arguments (2 given)
